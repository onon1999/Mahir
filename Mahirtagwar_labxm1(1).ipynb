# %%
#MAHIR TAGWAR
#2020-2-60-028

import pandas as pd

file_path = '/content/mushroom_cleaned.csv'  # Replace with the actual file name

# Attempt to read the file while skipping problematic lines
try:
    df = pd.read_csv(file_path, error_bad_lines=False)
except Exception as e:
    print(f"Error reading CSV: {e}")

# Display the first few rows of the DataFrame
print("First few rows of the dataset:")
print(df.head())

# Check for null values
print("\nChecking for null values in the dataset:")
print(df.isnull().sum())
# Out:
# Error reading CSV: read_csv() got an unexpected keyword argument 'error_bad_lines'
# First few rows of the dataset:
#    cap-diameter  cap-shape  gill-attachment  gill-color  stem-height  \
# 0          1372          2                2          10     3.807467
# 1          1461          2                2          10     3.807467
# 2          1371          2                2          10     3.612496
# 3          1261          6                2          10     3.787572
# 4          1305          6                2          10     3.711971
#
#    stem-width  stem-color    season  class
# 0        1545          11  1.804273    1.0
# 1        1557          11  1.804273    1.0
# 2        1566          11  1.804273    1.0
# 3        1566          11  1.804273    1.0
# 4        1464          11  0.943195    1.0
#
# Checking for null values in the dataset:
# cap-diameter       0
# cap-shape          0
# gill-attachment    0
# gill-color         0
# stem-height        0
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score

# Load the dataset
file_path = '/content/mushroom_cleaned.csv'  # Replace with the actual file name

# Attempt to read the file while skipping problematic lines
df = pd.read_csv(file_path, on_bad_lines='skip')

# Display the first few rows of the DataFrame
print("First few rows of the dataset:")
print(df.head())

# Check for null values
print("\nChecking for null values in the dataset:")
print(df.isnull().sum())

# Drop rows with null values
df = df.dropna()

# Verify that there are no more null values
print("\nNull values after dropping rows with nulls:")
print(df.isnull().sum())

# Extract features and target variable
X = df.drop('class', axis=1)  # Features
y = df['class']  # Target variable

# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Initialize and train the Logistic Regression classifier
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

# Predict the test set results for Logistic Regression
y_pred_log_reg = log_reg.predict(X_test)

# Initialize and train the Random Forest classifier
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, y_train)

# Predict the test set results for Random Forest
y_pred_rf = rf_clf.predict(X_test)

# Function to print evaluation metrics
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='macro')
    recall = recall_score(y_test, y_pred, average='macro')
    print(f'Accuracy: {accuracy:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')

# Evaluate and print the performance for both classifiers
print("\nLogistic Regression Performance:")
evaluate_model(y_test, y_pred_log_reg)

print("\nRandom Forest Performance:")
evaluate_model(y_test, y_pred_rf)
# Out:
# First few rows of the dataset:
#    cap-diameter  cap-shape  gill-attachment  gill-color  stem-height  \
# 0          1372          2                2          10     3.807467
# 1          1461          2                2          10     3.807467
# 2          1371          2                2          10     3.612496
# 3          1261          6                2          10     3.787572
# 4          1305          6                2          10     3.711971
#
#    stem-width  stem-color    season  class
# 0        1545          11  1.804273      1
# 1        1557          11  1.804273      1
# 2        1566          11  1.804273      1
# 3        1566          11  1.804273      1
# 4        1464          11  0.943195      1
#
# Checking for null values in the dataset:
# cap-diameter       0
# cap-shape          0
# gill-attachment    0
# gill-color         0
# stem-height        0
# stem-width         0
# stem-color         0
# season             0
# class              0
# ...

# %%
# Check for null values
print("\nChecking for null values in the dataset:")
print(df.isnull().sum())

# Drop rows with null values
df = df.dropna()

# Extract features and target variable
X = df.drop('class', axis=1)  # Features
y = df['class']  # Target variable

# Normalize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Initialize and train the Logistic Regression classifier
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

# Predict the test set results for Logistic Regression
y_pred_log_reg = log_reg.predict(X_test)

# Initialize and train the Random Forest classifier
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train, y_train)

# Predict the test set results for Random Forest
y_pred_rf = rf_clf.predict(X_test)

# Evaluate and print the performance for both classifiers
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='macro')
    recall = recall_score(y_test, y_pred, average='macro')
    print(f'Accuracy: {accuracy:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    return accuracy, precision, recall

print("\nLogistic Regression Performance:")
log_reg_accuracy, log_reg_precision, log_reg_recall = evaluate_model(y_test, y_pred_log_reg)

print("\nRandom Forest Performance:")
rf_accuracy, rf_precision, rf_recall = evaluate_model(y_test, y_pred_rf)

# Plot confusion matrix for Logistic Regression
log_reg_cm = confusion_matrix(y_test, y_pred_log_reg)
plt.figure(figsize=(8, 6))
sns.heatmap(log_reg_cm, annot=True, fmt='d', cmap='Blues', xticklabels=['edible', 'poisonous'], yticklabels=['edible', 'poisonous'])
plt.title('Confusion Matrix - Logistic Regression')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Plot confusion matrix for Random Forest
rf_cm = confusion_matrix(y_test, y_pred_rf)
plt.figure(figsize=(8, 6))
sns.heatmap(rf_cm, annot=True, fmt='d', cmap='Blues', xticklabels=['edible', 'poisonous'], yticklabels=['edible', 'poisonous'])
plt.title('Confusion Matrix - Random Forest')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Checking for null values in the dataset:
# cap-diameter       0
# cap-shape          0
# gill-attachment    0
# gill-color         0
# stem-height        0
# stem-width         0
# stem-color         0
# season             0
# class              0
# dtype: int64
#
# Logistic Regression Performance:
# Accuracy: 0.6448
# Precision: 0.6354
# Recall: 0.6241
#
# Random Forest Performance:
# Accuracy: 0.9944
# Precision: 0.9941
# Recall: 0.9944
