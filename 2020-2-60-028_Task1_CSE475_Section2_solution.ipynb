# %% [markdown]
# # **Assisment Task1 CSE475 Section1**

# %% [markdown]
# # Section 1

# %% [markdown]
# #### Import Pandas, Matplotlib, Seaborn

# %%
import pandas as pd
import seaborn
from matplotlib import pyplot as plt

# %% [markdown]
# #### Write and execute an import statement to import seaborn with alias sns

# %%
import seaborn as sns

# %% [markdown]
# #### Write and execute an import numpy under the alias np

# %%
import numpy as np

# %% [markdown]
# ##

# %% [markdown]
# #### Write and execute an import statement to import seaborn with alias sns

# %%
import seaborn as sns

# %% [markdown]
# #### Write and execute an import numpy under the alias np

# %%
import numpy as np

# %% [markdown]
# # Section 2

# %% [markdown]
# Define a variable called cse_475 whose value is "Assisment Task 1".
#
# Show the values assigned to these variables.

# %%
cse_475="Assisment Task 1"
print(cse_475)
# Out:
# Assisment Task 1

# %% [markdown]
# Load dataset called cereal, which is loaded as cereal. Let's select a few different rows to learn more about this.
#
# Select and show the cereal where calories is greater than 50.
#
# Select and show the cereal where calories is equal to protin.
#
# Select and show the cereal where shelf is not equal to cups.

# %%
df=pd.read_csv("/cereal.csv")
x=df[df.calories>50]
x
# Out:
#                        name mfr type  calories  protein  fat  sodium  fiber  \
# 0                 100% Bran   N    C        70        4    1     130   10.0
# 1         100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                  All-Bran   K    C        70        4    1     260    9.0
# 4            Almond Delight   R    C       110        2    2     200    1.0
# 5   Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# ..                      ...  ..  ...       ...      ...  ...     ...    ...
# 72                  Triples   G    C       110        2    1     250    0.0
# 73                     Trix   G    C       110        1    1     140    0.0
# 74               Wheat Chex   R    C       100        3    1     230    3.0
# 75                 Wheaties   G    C       100        3    1     200    3.0
# 76      Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
y=df[df.calories==df.protein]
y
# Out:
# Empty DataFrame
# Columns: [name, mfr, type, calories, protein, fat, sodium, fiber, carbo, sugars, potass, vitamins, shelf, weight, cups, rating]
# Index: []

# %%
z=df[df.shelf!=df.cups]
z
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 71          Total Whole Grain   G    C       100        3    1     200    3.0
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# Select rows of cereal such that the column sugars is equal to 10

# %%
a=df[df.sugars==10]
a
# Out:
#                                       name mfr type  calories  protein  fat  \
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 22                  Crispy Wheat & Raisins   G    C       100        2    1
# 27  Fruit & Fibre Dates; Walnuts; and Oats   P    C       120        3    2
# 36                      Honey Nut Cheerios   G    C       110        3    1
# 51                    Oatmeal Raisin Crisp   G    C       130        3    2
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 5      180    1.5   10.5      10      70        25      1    1.00  0.75
# 22     140    2.0   11.0      10     120        25      3    1.00  0.75
# 27     160    5.0   12.0      10     200        25      3    1.25  0.67
# 36     250    1.5   11.5      10      90        25      1    1.00  0.75
# 51     170    1.5   13.5      10     120        25      3    1.25  0.50
#
#        rating
# 5   29.509541
# 22  36.176196
# 27  40.917047
# ...

# %% [markdown]
# # Section 3

# %% [markdown]
# Plot eat Fruity Pebbles using the columns protin and suger
# from cereal.

# %%
y=df[df.name=="Fruity Pebbles"]
y
plt.scatter(y.protein,y.sugars	)

# %% [markdown]
# Select rows of cereal such that the column sugars is equal to 10

# %%
a=df[df.sugars==10]
a
# Out:
#                                       name mfr type  calories  protein  fat  \
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 22                  Crispy Wheat & Raisins   G    C       100        2    1
# 27  Fruit & Fibre Dates; Walnuts; and Oats   P    C       120        3    2
# 36                      Honey Nut Cheerios   G    C       110        3    1
# 51                    Oatmeal Raisin Crisp   G    C       130        3    2
#
#     sodium  fiber  carbo  sugars  potass  vitamins  shelf  weight  cups  \
# 5      180    1.5   10.5      10      70        25      1    1.00  0.75
# 22     140    2.0   11.0      10     120        25      3    1.00  0.75
# 27     160    5.0   12.0      10     200        25      3    1.25  0.67
# 36     250    1.5   11.5      10      90        25      1    1.00  0.75
# 51     170    1.5   13.5      10     120        25      3    1.25  0.50
#
#        rating
# 5   29.509541
# 22  36.176196
# 27  40.917047
# ...

# %% [markdown]
# # Section 4

# %% [markdown]
# Display the first five rows of the DataFrame and determine which columns to plot.
#
# Create a scatter plot of the data in sugar.

# %%
df.head()
plt.scatter(df.sugars,df.fat)

# %% [markdown]
# Create a histogram of the column weight from the DataFrame cereal

# %%
plt.hist(df.weight)
# Out:
# (array([ 2.,  0.,  0.,  1.,  0., 64.,  0.,  2.,  6.,  2.]),
#  array([0.5, 0.6, 0.7, 0.8, 0.9, 1. , 1.1, 1.2, 1.3, 1.4, 1.5]),
#  <BarContainer object of 10 artists>)
